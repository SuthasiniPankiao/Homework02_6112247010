# %%
#การประกาศตัวแปร
from __future__ import print_function, division

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import thinkdsp
import thinkplot
import thinkstats2 

import numpy as np

from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

# %%
#การสุ่มเพื่อให้เกิดเสียงรบกวน
thinkdsp.random_seed(10)

# %%
#เป็นการสร้างเสียงรบกวนกับการรวมคลื่นที่สุ่มมา ถ้าต้องการเสียงรบกวนเพิ่มขึ้นให้เพิ่มduration =ระยะเวลาที่ทำให้เกิดเสียง
signal = thinkdsp.UncorrelatedUniformNoise()
wave = signal.make_wave(duration=10, framerate=5512)
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
